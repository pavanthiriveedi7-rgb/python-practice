# %% [markdown]
# **Python OOP**
# OOP stands for Object-Oriented Programming.
#
# Python is an object-oriented language, allowing you to structure your code using classes and objects for better organization and reusability.
#
# What are **Classes** and **Objects**?
#
#
# Classes and objects are the two core concepts in object-oriented programming.
#
# A class defines what an object should look like, and an object is created based on that class. For example:
#
# Class  ---  	Objects
#
# Fruit	  -->    Apple, Banana, Mango
#
# Car     -->  	Volvo, Audi, Toyota
#
# Almost everything in Python is an object, with its properties and methods.
#
# A Class is like an object constructor, or a "blueprint" for creating objects.

# %%
# Create a class named MyClass, with a property named x:
class MyClass:
  x = 5

# %%
# Create an object named p1, and print the value of x:
class MyClass:
  x = 5

p1 = MyClass()
print(p1.x)
# Out:
# 5

# %%
p1 = MyClass()
p2 = MyClass()
p3 = MyClass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %% [markdown]
# **pass Statemen**t:
#
#
# class definitions cannot be empty, but if you for some reason have a class definition with no content, put in the pass statement to avoid getting an error.

# %%
class Myclass:
  pass

# %% [markdown]
# **__init__() Method**:
#
# All classes have a built-in method called __init__(), which is always executed when the class is being initiated.
#
# The __init__() method is used to assign values to object properties, or to perform operations that are necessary when the object is being created.

# %%
#Create a class named Person, use the __init__() method to assign values for name and age:

class Myclass:
  def __init__(self,name,age):
    self.name = name
    self.age = age

p1 = Myclass("pavan",18)
print(p1)
print(p1.name)
print(p1.age)
# Out:
# ...
# pavan
# 18

# %%
class Person:
  def __init__(self, name, age, city, country):
    self.name = name
    self.age = age
    self.city = city
    self.country = country

p1 = Person("Pavan", 30, "vijayawada", "India")

print(p1.name)
print(p1.age)
print(p1.city)
print(p1.country)
print(f" Let me Introduce My-self to I am {p1.name} from {p1.city} and my age is {p1.age} and finally  i am {p1.country}")
# Out:
# Pavan
# 30
# vijayawada
# India
#  Let me Introduce My-self to I am Pavan from vijayawada and my age is 30 and finally  i am India

# %%
# Without the __init__() method, you would need to set properties manually for each object:

class Person:
  pass

p1 = Person()
p1.name = "pavan"
p1.age = 18

print(p1.name)
print(p1.age)
# Out:
# pavan
# 18

# %% [markdown]
# **self Parameter**:
#
# The self parameter is a reference to the current instance of the class.
#
# It is used to access properties and methods that belong to the class.

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print("Hello, my name is " + self.name)

  def old(self):
    print(self.age)

p1 = Person("Brucell", 19)
p1.greet()
p1.old()
# Out:
# Hello, my name is Brucell
# 19

# %% [markdown]
# It does not have to be named self, you can call it whatever you like, but it has to be the first parameter of any method in the class

# %%
class Person:
  def __init__(Bypavan, name, age):
    Bypavan.name = name
    Bypavan.age = age

  def greet(Sam):
    print("Hello, my name is " + Sam.name)

  def old(Ruku):
    print(Ruku.age)

p1 = Person("Brucell", 19)
p1.greet()
p1.old()
# Out:
# Hello, my name is Brucell
# 19

# %%
class Calculator:
  def add(self, a, b):
    return a + b

  def multiply(self, a, b):
    return a * b

calc = Calculator()
print(calc.add(5, 3))
print(calc.multiply(4, 7))
# Out:
# 8
# 28

# %%
class Calculator:
  def sub(self,a,b):
    return a - b
  def div(self,a,b):
    return a/b
calc = Calculator()
print(calc.sub(9,6))
print(calc.div(9,6))
# Out:
# 3
# 1.5

# %% [markdown]
# Methods can modify the properties of an object

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def celebrate_birthday(self):
    self.age += 1
    print(f"Happy birthday! You are now {self.age}")

p1 = Person("ram", 8)
p1.celebrate_birthday()
p1.celebrate_birthday()
# Out:
# Happy birthday! You are now 9
# Happy birthday! You are now 10

# %%
#  __str__() Method

class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name} ({self.age})"

p1 = Person("ram", 8)
print(p1)
# Out:
# ram (8)

# %%
class Playlist:
  def __init__(self, name):
    self.name = name
    self.songs = []

  def add_song(self, song):
    self.songs.append(song)
    print(f"Added: {song}")

  def remove_song(self, song):
    if song in self.songs:
      self.songs.remove(song)
      print(f"Removed: {song}")

  def show_songs(self):
    print(f"Playlist '{self.name}':")
    for song in self.songs:
      print(f"- {song}")

my_playlist = Playlist("Favorites")
my_playlist.show_songs()
my_playlist.add_song("Jai Ballayya.....  ")
my_playlist.add_song("Jai NTR Jai NTR....")
my_playlist.remove_song("Jai Ballayya.....")
my_playlist.remove_song("Jai NTR Jai NTR....")
my_playlist.show_songs()
# Out:
# Playlist 'Favorites':
# Added: Jai Ballayya.....
# Added: Jai NTR Jai NTR....
# Removed: Jai NTR Jai NTR....
# Playlist 'Favorites':
# - Jai Ballayya.....

# %% [markdown]
# **Python Inheritance**
#
# Inheritance allows us to define a class that inherits all the methods and properties from another class.
#
# **Parent class** is the class being inherited from, also called base class.
#
# **Child class** is the class that inherits from another class, also called derived class.

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("pavan", "kumar")
x.printname()
# Out:
# pavan kumar

# %%
# Create a class named Student, which will inherit the properties and methods from the Person class:

class Student(Person):
  pass

# %% [markdown]
# Now the Student class has the same properties and methods as the Person class.

# %%
class Person:                                   #parent class
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):                                 # child class
  def __init__(self, fname, lname):
    Person.__init__(self, fname, lname)

x = Student("pavan", "kumar")
x.printname()
# Out:
# pavan kumar

# %% [markdown]
# *super() Function*::
#
# Python also has a super() function that will make the child class inherit all the methods and properties from its parent

# %%
class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)

x = Student("pavan", "Kumar")
x.printname()
# Out:
# pavan Kumar

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)
    self.graduationyear = 2027

x = Student("pavan", "kumar")
print(x.graduationyear)
#print(x.firstname)
#print(x.lastname)
# Out:
# 2027

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year
  def greet(self):
    print("Welcome",self.printname, "In the since ",{self.firstname}, {self.lastname}, "and i will be graduate in ", {self.graduationyear})

x = Student("pavan", "kumar", 2027)
print(x.graduationyear)
x.greet()

print(x)
# Out:
# 2027
# Welcome <bound method Person.printname of <__main__.Student object at 0x798bf8ebf7d0>> In the since  {'pavan'} {'kumar'} and i will be graduate in  {2027}
# ...
