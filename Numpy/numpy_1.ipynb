# %% [markdown]
# **NumPy ufuncs**
#
#
# ufuncs stands for "Universal Functions" and they are NumPy functions that operate on the ndarray object.
#
# ufuncs are used to implement vectorization in NumPy which is way faster than iterating over elements.

# %%
#Without ufunc, we can use Python's built-in zip() method

x = [1,2,3,3]
y = [4,5,6,7]
for i,j in zip(x,y):

  print(i,j)
# Out:
# 1 4
# 2 5
# 3 6
# 3 7

# %%
# Without ufunc, we can use Python's built-in zip() method
x = [1,2,3,4]
y = [3,4,5,6]
z = []
for i,j in zip(x,y):
  z.append(i+j)
  print(z)
# Out:
# [4]
# [4, 6]
# [4, 6, 8]
# [4, 6, 8, 10]

# %%
import numpy as np
x = [1,2,35,6]
y = [9,8,7,6]
z = np.add(x,y)
print(z)
# Out:
# [10 10 42 12]

# %%
import numpy as np
x = [1,2,3,4]
y = [3,4,5,6]
z = np.subtract(x,y)
print(z)
# Out:
# [-2 -2 -2 -2]

# %%
import numpy as np
def myadd(x,y):
  return x+y
myadd = np.frompyfunc(myadd, 2, 1)
print(myadd([1, 2, 3, 4], [5, 6, 7, 8]))
# Out:
# [6 8 10 12]

# %%
import numpy as np
print(type(np.add))
# Out:
# <class 'numpy.ufunc'>

# %%
import numpy as np
x = np.array([9,8,6,2,4,5])
y = np.array([7,5,6,2,1,3])
print(np.add(x,y))
# Out:
# [16 13 12  4  5  8]

# %%
import numpy as np
x = np.array([9,8,6,2,4,5])
y = np.array([7,5,6,2,1,3])
print(np.subtract(x,y))
# Out:
# [2 3 0 0 3 2]

# %%
import numpy as np
x = np.array([9,8,6,2,4,5])
y = np.array([7,5,6,2,1,3])
print(np.multiply(x,y))
# Out:
# [63 40 36  4  4 15]

# %%
import numpy as np
x = np.array([9,8,6,2,4,5])
y = np.array([7,5,6,2,1,3])
print(np.divide(x,y))
# Out:
# [1.28571429 1.6        1.         1.         4.         1.66666667]

# %%
import numpy as np
x = np.array([9,8,6,2,4,5])
y = np.array([7,5,6,2,1,3])
print(np.power(x,y))
print(np.mod(x,y))
print(np.remainder(x,y))
print(np.absolute(x,y))
# Out:
# [4782969   32768   46656       4       4     125]
# [2 3 0 0 0 2]
# [2 3 0 0 0 2]
# [9 8 6 2 4 5]

# %%
import numpy as np
arr = np.trunc([-3.1666, 3.6667])
print(arr)
arr = np.around([-3.1666, 3.6667])
print(arr)
arr  = np.floor([-3.1666, 3.6667])
print(arr)
arr = np.fix([-3.1666, 3.6667])
print(arr)
arr = np.ceil([-3.1666, 3.6667])
print(arr)
# Out:
# [-3.  3.]
# [-3.  4.]
# [-4.  3.]
# [-3.  3.]
# [-3.  4.]

# %%
import numpy as np
arr = np.arange(1,10)
print(np.log2(arr))
# Out:
# [0.         1.         1.5849625  2.         2.32192809 2.5849625
#  2.80735492 3.         3.169925  ]

# %%
import numpy as np
arr = np.arange(1,10)
print(np.log10(arr))
# Out:
# [0.         0.30103    0.47712125 0.60205999 0.69897    0.77815125
#  0.84509804 0.90308999 0.95424251]

# %%
import numpy as np
arr = np.arange(1,10)
print(np.log(arr))
#print(np.loge(arr))
# Out:
# [0.         0.69314718 1.09861229 1.38629436 1.60943791 1.79175947
#  1.94591015 2.07944154 2.19722458]

# %%
import numpy as np
x = 10
y = 45
k = np.lcm(x,y)
print(k)
# Out:
# 90

# %%
import numpy as np
x = 99
y = 66
k = np.lcm(x,y)
c = np.gcd(x,y)
print(k)
print(c)
# Out:
# 198
# 33

# %%
import numpy as pa1
x = 88
y = 125
k = pa1.lcm(x,y)
print(k)
# Out:
# 11000

# %%
import numpy as np
x = np.sin(np.pi/2)
print(x)
# Out:
# 1.0

# %%
import numpy as np
x = np.array([np.pi/2,np.pi/3,np.pi/4])
print(np.sin(x))
# Out:
# [1.         0.8660254  0.70710678]

# %%
print(np.cos(x))
# Out:
# [6.12323400e-17 5.00000000e-01 7.07106781e-01]

# %%
print(np.tan(x))
# Out:
# [1.63312394e+16 1.73205081e+00 1.00000000e+00]

# %%
import numpy as np
x = np.sin([np.pi/2,np.pi/3,np.pi/4])
print(x)
# Out:
# [1.         0.8660254  0.70710678]

# %%
import numpy as np
x = np.cos([np.pi/2,np.pi/3,np.pi/4])
x1 = np.tan([np.pi/2,np.pi/3,np.pi/4])
x2 = np.sin([np.pi/2,np.pi/3,np.pi/4])
print(x2)
print(x)
print(x1)
# Out:
# [1.         0.8660254  0.70710678]
# [6.12323400e-17 5.00000000e-01 7.07106781e-01]
# [1.63312394e+16 1.73205081e+00 1.00000000e+00]

# %%
print(np.arcsin(x))
# Out:
# [       nan        nan 0.90333911]
# /tmp/ipython-input-835714997.py:1: RuntimeWarning: invalid value encountered in arcsin
#   print(np.arcsin(x))

# %%
print(np.arccos(x))
print(np.arctan(x))
# Out:
# nan
# 1.473050747060915
# /tmp/ipython-input-814762016.py:1: RuntimeWarning: invalid value encountered in arccos
#   print(np.arccos(x))

# %%
# NumPy provides the hypot() function that takes the base and perpendicular values and produces hypotenues based on pythagoras theorem.
import numpy as np
base = 2
perpend = 10
x = np.hypot(base,perpend)
print(x)
# Out:
# 10.198039027185569

# %%
import numpy as np
x = np.array([np.pi/2,np.pi/3,np.pi/4])
print(np.sinh(x))
# Out:
# [2.3012989  1.24936705 0.86867096]

# %%
print(np.cosh(x))
print(np.tanh(x))
print(np.arctanh(x))
print(np.arcsin(x))
# Out:
# [2.50917848 1.60028686 1.32460909]
# [0.91715234 0.78071444 0.6557942 ]
# [       nan        nan 1.05930617]
# [       nan        nan 0.90333911]
# /tmp/ipython-input-1539168715.py:3: RuntimeWarning: invalid value encountered in arctanh
#   print(np.arctanh(x))
# /tmp/ipython-input-1539168715.py:4: RuntimeWarning: invalid value encountered in arcsin
#   print(np.arcsin(x))

# %%
import numpy as np
arr = np.array([1, 1, 1, 2, 3, 4, 5, 5, 6, 7])
x = np.unique(arr)
print(x)
# Out:
# [1 2 3 4 5 6 7]

# %%
import numpy as np

x = np.array([1, 2, 3, 4])
y = np.array([3, 4, 5, 6])
v = np.union1d(x,y)
print(v)
# Out:
# [1 2 3 4 5 6]

# %%
import numpy as np

x = np.array([1, 2, 3, 4])
y = np.array([3, 4, 5, 6])
v = np.intersect1d(x,y)
print(v)
# Out:
# [3 4]

# %%
import numpy as np

x = np.array([1, 2, 3, 4])
y = np.array([3, 4, 5, 6])
v = np.setdiff1d(x,y)
print(v)
# Out:
# [1 2]
