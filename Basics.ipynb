# %% [markdown]
# **Python Syntax**
#
# Execute Python Syntax

# %%
print("Hello Pavan!")
# Out:
# Hello World!

# %% [markdown]
# Python Indentation
# Indentation refers to the spaces at the beginning of a code line.
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# Python uses indentation to indicate a block of code.

# %%
if 5>2:
  print("5 is grater than 2")
# Out:
# 5 is grater than 2

# %%
if 5 > 2:
 print("Five is greater than two!")
        print("Five is greater than two!")
# Out:
#   File "/tmp/ipython-input-3430240237.py", line 3
#     print("Five is greater than two!")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# You have to use the same number of spaces in the same block of code, otherwise Python will give you an error

# %% [markdown]
# Python Variables
# In Python, variables are created when you assign a value to it
#
# Python has no command for declaring a variable.
#
# Example

# %%
x = 5
y = "Hello, Pavan!"
print(x)
print(y)
# Out:
# 5
# Hello, Pavan!

# %% [markdown]
# **Comments**
#
# Python has commenting capability for the purpose of in-code documentation.
#
# Comments start with a #, and Python will render the rest of the line as a comment:

# %%
#This is a comment.
print("Hello, Pavan!")
# Out:
# Hello, Pavan!

# %% [markdown]
# **Statements**
#
# A computer program is a list of "instructions" to be "executed" by a computer.
#
# In a programming language, these programming instructions are called statements.
#
# In Python, a statement usually ends when the line ends. You do not need to use a semicolon (;) like in many other programming languages (for example, Java or C).

# %%
print("Pujith kumar is a funny guy! ")
# Out:
# Pujith kumar is a funny guy!

# %% [markdown]
# Many Statements
# Most Python programs contain many statements.
#
# The statements are executed one by one, in the same order as they are written

# %%
print("Hello Pavan!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello Pavan!
# Have a good day.
# Learning Python is fun!

# %% [markdown]
#  if you put two statements on the same line without a separator (newline or ;), Python will give an error:

# %%
print("Hello Pavan!");print("Have a good day.");print("Learning Python is fun!"
# Out:
#   File "/tmp/ipython-input-1992686860.py", line 1
#     print("Hello Pavan!");print("Have a good day.");print("Learning Python is fun!"
#                                                                                    ^
# SyntaxError: incomplete input

# %% [markdown]
# **Put each statement on its own line so your code is easy to understand.**

# %% [markdown]
# **Multiline Comments**
#
# Python does not really have a syntax for multiline comments.
#
# To add a multiline comment you could insert a # for each line:

# %%
#This is a comment
#written in
#more than just one line
print("Hello, pujith!")
# Out:
# Hello, pujith!

# %% [markdown]
# **Variables**
#
# Variables are containers for storing data values.

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %% [markdown]
# **Casting**
#
# If you want to specify the data type of a variable, this can be done with casting

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0

# %% [markdown]
# Get the Type:
#
# the data type of a variable with the type() function.

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Single or Double Quotes?

# %%
x = "pavan"
print(x)
# is the same as
x = 'pavan'
print(x)
# Out:
# pavan
# pavan

# %% [markdown]
# **Variable Names**
#
#
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
#
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)
# A variable name cannot be any of the Python keywords.

# %%
myvar = "venky"
my_var = "venky"
_my_var = "venky"
myVar = "venky"
MYVAR = "venky"
myvar2 = "venky""

# %% [markdown]
# **Multi Words Variable Names**
# Variable names with more than one word can be difficult to read.
#
# There are several techniques you can use to make them more readable:
#
# **Camel Case**
# Each word, except the first, starts with a capital letter

# %%
myVariableName = "pujith"
print(myVariableName)
# Out:
# pujith

# %% [markdown]
# **Pascal Case**
# Each word starts with a capital letter:

# %%
MyVariableName = "Pavan"
print(MyVariableName)
# Out:
# Pavan

# %% [markdown]
# **Snake Case**
# Each word is separated by an underscore character:

# %%
my_variable_name = "gouse"
print(my_variable_name)
# Out:
# gouse

# %% [markdown]
# Many Values to Multiple Variables

# %%
x, y, z = "Pavan", "gouse", "pujith"
print(x)
print(y)
print(z)
# Out:
# Pavan
# gouse
# pujith

# %%
x = y = z = "Pavan"
print(x)
print(y)
print(z)
# Out:
# Pavan
# Pavan
# Pavan

# %% [markdown]
# **Unpack a Collection**
# If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. This is called unpacking.

# %%
Friends = ["Pavan", "pujith", "gouse"]
x, y, z = Friends
print(x)
print(y)
print(z)
# Out:
# Pavan
# pujith
# gouse

# %%
x = "Python"
y = "is"
z = "wonderfull!"
print(x, y, z)
# Out:
# Python is wonderfull!
